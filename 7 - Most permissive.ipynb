# %%
from colomoto.minibn import *
import mpbn
# Out:
# <script type="text/javascript" id="colomoto-setup-6520404" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
# function detect_import(cell, module) {
#     var code = cell.get_text();
#     code = code.replace(/\\\n/g, "");
#     var lines = code.split("\n");
#     var r_simple = new RegExp("^("+module+")$");
#     var r_alias = new RegExp("^"+module+"\\s+as\\s+(\\w+)$");
#     for (var i = 0; i < lines.length; ++i) {
#         if (/^import\s/.test(lines[i])) {
#             code = lines[i].substr(7);
#             var parts = code.split(",")
#             for (var j = 0; j < parts.length; ++j) {
#                 code = parts[j].trim();
#                 var m = code.match(r_simple);
#                 if (!m) {
#                     m = code.match(r_alias);
#                 }
#                 if (m) {
#                     return m[1];
#                 }
#             }
#         }
#     }
#     return module;
# }
#
# ...

# %%
i3ffl = BooleanNetwork({
    "x1": True,
    "x2": "x1",
    "x3": "x2 & !x1",
})
i3ffl.influence_graph()
# Out:
# # computing graph layout...

# %%
GeneralAsynchronousDynamics(i3ffl).partial_dynamics({"x1": 0, "x2": 0, "x3": 0})
# Out:
# # computing graph layout...

# %%
mpbn.MostPermissiveDynamics(i3ffl).partial_dynamics(i3ffl.zero())
# Out:
# # computing graph layout...
